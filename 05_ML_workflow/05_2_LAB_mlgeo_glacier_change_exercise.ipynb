# %% [markdown]
# # ___
#
# # [ Machine Learning in Earth Observation and Geography ]
#
# </br>
#
# <div>
# <img src="attachment:image.png" width="400">
# </div>
#
# ---
#
# Lecturer: *Lukas Brodsky lukas.brodsky@natur.cuni.cz*
#
# **Department of Applied Geoinformatics and Carthography, Charles University**
#
# ___

# %% [markdown]
# ### 1.1 The Problem
#
# TASK: WHhat area retreated the Columbia glacier between 1986 and 2022?
#
# In this work, you shall apply Machine Learning (ML) approach to **detect changed area of glacier**.
#
#
# ### 1.2 Assumptions
#
# * The problem is a multivariate classification (will use multiple features / bands of Landsat-5 and Landsat-8);
# * There is no continuous flow of data, hence batch learning shall be applied;
# * The Spectral signatures in the Landsat bands are good predictors of ices, debris, water, etc.;
# * There are enough variables (features) to do the classification and change detectyion.
#
#
# ### 1.3 Expected results
#
# * Machine Learning model to predict the status for t1 and t2 and apply change ananlysis technique (any) to analyze the change.
# ___

# %%
# Imports 
pass

# %%
# Input data
image_1986_fn = './Columbia_glacier/L5_19860728_Columbia_glacier.tif'
image_2022_fn = './Columbia_glacier/L8_20220724_Columbia_glacier.tif'

# %% [markdown]
# ### 2. Exploratory Data Analysis (EDA)

# %%
pass

# %% [markdown]
# ### 3. Data Preparation

# %%
pass

# %% [markdown]
# ### 4. Select and Train Model

# %%
pass

# %% [markdown]
# ### 5. Model Fine-tuning

# %%
pass

# %% [markdown]
# ### 6. Present Results (and interpret)

# %%
pass
