# %% [markdown]
# # ___
#
# # [ Machine Learning in Earth Observation and Geography ]
#
# </br>
#
# <div>
# <img src="attachment:image.png" width="400">
# </div>
#
# ---
#
# Lecturer: *Lukas Brodsky lukas.brodsky@natur.cuni.cz*
#
# **Department of Applied Geoinformatics and Carthography, Charles University**
#
# ___

# %% [markdown]
# # Rasterio
#
# Working with rasters in Python!

# %% [markdown]
# ## Documentation
#
#
# Please refer to **[Rasterio official documentation](https://rasterio.readthedocs.io/en/stable/)**

# %% [markdown]
# ## 1. Reading raster

# %% [markdown]
# ### Library import

# %%
# ! pip install rasterio 

# https://rasterio.readthedocs.io/en/stable/installation.html
# python -m pip install --user -U pip
# GDAL_CONFIG=/path/to/gdal-config python -m pip install --user --no-binary rasterio rasterio

# %%
import os
import rasterio
import numpy as np
print(rasterio.__version__)

import matplotlib.pyplot as plt
# Out:
# 1.2.10

# %% [markdown]
# ### Data

# %%
os.listdir()
# Out:
# ['04_2_LAB_mlgeo_GeoPython_geopandas.ipynb',
#  '04_1_LAB_mlgeo_GeoPython_rasterio.ipynb',
#  '.ipynb_checkpoints',
#  '04_3_LAB_mlgeo_GeoPython_geopandas_meets_rasterio.ipynb']

# %%
# CHANGE TO YOUR PATH!!!
path = '/Users/lukas/Work/prfuk/vyuka/erasmus_ml_geography/data/'
# path = 'C:\Downloads\Machine Learning\data' -> WRONG! 
# path = 'C:\\Downloads\\Machine_Learning\\data' -> GOOD 
filename = 'S2A_T33UVR_20180703T101029.tif'
fnpath = os.path.join(path, filename)
os.path.isfile(fnpath)
# Out:
# True

# %%
print(fnpath)
# Out:
# /Users/lukas/Work/prfuk/vyuka/erasmus_ml_geography/data/S2A_T33UVR_20180703T101029.tif

# %%
# Read the iamge 
ds = rasterio.open(fnpath)
ds
# Out:
# <open DatasetReader name='/Users/lukas/Work/prfuk/vyuka/erasmus_ml_geography/data/S2A_T33UVR_20180703T101029.tif' mode='r'>

# %% [markdown]
# ### Metadata

# %%
print(f'Dataset: {ds}')
print(f'Typ datasetu: {type(ds)}')
# Out:
# Dataset: <open DatasetReader name='/Users/lukas/Work/prfuk/vyuka/erasmus_ml_geography/data/S2A_T33UVR_20180703T101029.tif' mode='r'>
# Typ datasetu: <class 'rasterio.io.DatasetReader'>

# %%
# Image metadata 
print(f'Bands: {ds.count}') # features for ML 
print(f'Image width: {ds.width}')
print(f'Image height: {ds.height}')
# Out:
# Bands: 12
# Image width: 2292
# Image height: 1364

# %%
# Raster file metadata 
meta = ds.meta
print(type(meta))
print('Metadata od the dataset: ...')
for k in meta:
    print(k, meta[k])
# Out:
# <class 'dict'>
# Metadata od the dataset: ...
# driver GTiff
# dtype uint8
# nodata nan
# width 2292
# height 1364
# count 12
# crs EPSG:32633
# transform | 10.00, 0.00, 447370.00|
# | 0.00,-10.00, 5554080.00|
# | 0.00, 0.00, 1.00|

# %%
# Bbox
print(f'Bbox: {ds.bounds}')
# Out:
# Bbox: BoundingBox(left=447370.0, bottom=5540440.0, right=470290.0, top=5554080.0)

# %%
# Transformation parameters 
# print(f'Geotransformation parameters: {ds.transform}')

# %% [markdown]
# ### Reading bands and applying map algebra
# (to be replaced by Machine Learning modelling in the next tasks)

# %%
B1 = ds.read(1)
print(f'Typ pole hodnot: {type(B1)}')
# Out:
# Typ pole hodnot: <class 'numpy.ndarray'>

# %%
B1.shape
# Out:
# (1364, 2292)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(B1, vmin=0, vmax=40, cmap='gray') 
plt.colorbar()

# %%
# Read more bands and calculate NDVI
RED = ds.read(3).astype(np.float32) 
NIR = ds.read(4).astype(np.float32)
print(f'Data type: {RED.dtype}')
# Out:
# Data type: float32

# %%
RED
# Out:
# array([[24., 24., 24., ...,  3.,  4.,  4.],
#        [23., 24., 25., ...,  3.,  3.,  3.],
#        [24., 25., 26., ...,  4.,  3.,  2.],
#        ...,
#        [23., 22., 22., ..., 32., 35., 25.],
#        [22., 23., 22., ..., 35., 33., 23.],
#        [22., 22., 22., ..., 30., 32., 30.]], dtype=float32)

# %%
# NDVI calculation
NDVI = (NIR - RED) / (NIR + RED)
print(type(NDVI))
print(NDVI.min(), NDVI.max())
# Out:
# <class 'numpy.ndarray'>
# -1.0 1.0

# %%
plt.imshow(NDVI, vmin=0.0, vmax=0.8)
plt.colorbar()

# %% [markdown]
# ## 2. Writing raster file

# %%
# prepare metadata
meta = ds.meta
print(f'Metadata datasetu: {meta}')
# Out:
# Metadata datasetu: {'driver': 'GTiff', 'dtype': 'uint8', 'nodata': nan, 'width': 2292, 'height': 1364, 'count': 12, 'crs': CRS.from_epsg(32633), 'transform': Affine(10.0, 0.0, 447370.0,
#        0.0, -10.0, 5554080.0)}

# %%
# update what is needed
meta["dtype"] = "float32"
meta['count'] = 1 # 1 band

# %%
print(f'Metadata datasetu: {meta}')
# Out:
# Metadata datasetu: {'driver': 'GTiff', 'dtype': 'float32', 'nodata': nan, 'width': 2292, 'height': 1364, 'count': 1, 'crs': CRS.from_epsg(32633), 'transform': Affine(10.0, 0.0, 447370.0,
#        0.0, -10.0, 5554080.0)}

# %%
# write the raster 
out_pthfn = os.path.join(path, 'Sentinel-2_ndvi.tif')

with rasterio.open(out_pthfn, 'w', **meta) as dst:
    dst.write_band(1, NDVI)

# %%
if os.path.isfile(out_pthfn):
    print('File Sentinel-2_ndvi.tif is written to the filesystem.')
    print(f"The size is: {os.path.getsize(out_pthfn) / 1000000} MB.")
# Out:
# File Sentinel-2_ndvi.tif is written to the filesystem.
# The size is: 12.513708 MB.
